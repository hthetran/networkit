# %%
import pandas as pd
import matplotlib.pyplot as plt

#f, axarr = plt.subplots(2, sharex=True)
#axarr[0].plot(x, y)
#axarr[0].set_title('Sharing X axis')
#axarr[1].scatter(x, y)
#f, axarr = plt.subplots(3, sharex=True)
#es_pldhh = df.loc[(df['Gen'] == 'PLDHH') & (df['Randomizer'] == 'NETWORKIT_ES')]
#axarr[0].scatter(es_pldhh['Thinning'], es_pldhh['Independence-Rate'], s=5)

# Data Format:
# Label, Runlength, Gen, Randomizer, PID, Thinning, Mu, Nodes, Param1, Param2, Param3, Independence-Rate
df = pd.read_csv("output/DATA.dat", sep='\t')
df[['Runlength','PID', 'Thinning', 'Mu', 'Nodes', 'Independence-Rate']] = df[['Runlength','PID', 'Thinning', 'Mu', 'Nodes', 'Independence-Rate']].apply(pd.to_numeric)

# Edge-Switching Markov Chain
print("Edge-Switching Markov Chain")
# PLDHH
df.loc[df['Label'] == 'ES_PARTICULAR_100'].plot(kind='scatter', x='Thinning', y='Independence-Rate', s=5)
plt.title("Single Source Powerlaw graph: $n = 100, \gamma = -2, mindeg = 1, maxdeg = 100$")
plt.xlim([0, 310])
plt.ylim([0, 1])
plt.show()

df.loc[(df['Nodes'] == 100) & (df['Gen'] == 'PLDHH') & (df['Randomizer'] == 'NETWORKIT_ES') & (df['Param3'] == '100') & (df['Param2'] == '1')].plot(kind='scatter', x='Thinning', y='Independence-Rate', s=5)
plt.title("Powerlaw graph: $n = 100, \gamma = -2, mindeg = 1, maxdeg = 100$")
plt.xlim([0, 310])
plt.ylim([0, 1])
plt.show()

df.loc[(df['Nodes'] == 200) & (df['Gen'] == 'PLDHH') & (df['Randomizer'] == 'NETWORKIT_ES') & (df['Param3'] == '200') & (df['Param2'] == '1')].plot(kind='scatter', x='Thinning', y='Independence-Rate', s=5)
plt.title("Powerlaw graph: $n = 200, \gamma = -2, mindeg = 1, maxdeg = 200$")
plt.xlim([0, 310])
plt.ylim([0, 1])
plt.show()

df.loc[(df['Nodes'] == 500) & (df['Gen'] == 'PLDHH') & (df['Randomizer'] == 'NETWORKIT_ES') & (df['Param3'] == '500') & (df['Param2'] == '1')].plot(kind='scatter', x='Thinning', y='Independence-Rate', s=5)
plt.title("Powerlaw graph: $n = 500, \gamma = -2, mindeg = 1, maxdeg = 500$")
plt.xlim([0, 310])
plt.ylim([0, 1])
plt.show()

df.loc[(df['Nodes'] == 1000) & (df['Gen'] == 'PLDHH') & (df['Randomizer'] == 'NETWORKIT_ES') & (df['Param3'] == '1000') & (df['Param2'] == '1')].plot(kind='scatter', x='Thinning', y='Independence-Rate', s=5)
plt.title("Powerlaw graph: $n = 1000, \gamma = -2, mindeg = 1, maxdeg = 1000$")
plt.xlim([0, 310])
plt.ylim([0, 1])
plt.show()

df.loc[(df['Nodes'] == 2000) & (df['Gen'] == 'PLDHH') & (df['Randomizer'] == 'NETWORKIT_ES') & (df['Param3'] == '1000') & (df['Param2'] == '1')].plot(kind='scatter', x='Thinning', y='Independence-Rate', s=5)
plt.title("Powerlaw graph: $n = 2000, \gamma = -2, mindeg = 1, maxdeg = 1000$")
plt.xlim([0, 310])
plt.ylim([0, 1])
plt.show()

df.loc[(df['Nodes'] == 5000) & (df['Gen'] == 'PLDHH') & (df['Randomizer'] == 'NETWORKIT_ES') & (df['Param3'] == '1000') & (df['Param2'] == '1')].plot(kind='scatter', x='Thinning', y='Independence-Rate', s=5)
plt.title("Powerlaw graph: $n = 5000, \gamma = -2, mindeg = 1, maxdeg = 1000$")
plt.xlim([0, 310])
plt.ylim([0, 1])
plt.show()

df.loc[(df['Nodes'] == 10000) & (df['Gen'] == 'PLDHH') & (df['Randomizer'] == 'NETWORKIT_ES') & (df['Param3'] == '1000') & (df['Param2'] == '1')].plot(kind='scatter', x='Thinning', y='Independence-Rate', s=5)
plt.title("Powerlaw graph: $n = 10000, \gamma = -2, mindeg = 1, maxdeg = 1000$")
plt.xlim([0, 310])
plt.ylim([0, 1])
plt.show()

df.loc[(df['Nodes'] == 1000) & (df['Gen'] == 'PLDHH') & (df['Randomizer'] == 'NETWORKIT_ES') & (df['Param3'] == '1000') & (df['Param2'] == '5')].plot(kind='scatter', x='Thinning', y='Independence-Rate', s=5)
plt.title("Powerlaw graph: $n = 1000, \gamma = -2, mindeg = 5, maxdeg = 1000$")
plt.xlim([0, 310])
plt.show()

df.loc[(df['Nodes'] == 1000) & (df['Gen'] == 'PLDHH') & (df['Randomizer'] == 'NETWORKIT_ES') & (df['Param3'] == '1000') & (df['Param2'] == '50')].plot(kind='scatter', x='Thinning', y='Independence-Rate', s=5)
plt.title("Powerlaw graph: $n = 1000, \gamma = -2, mindeg = 50, maxdeg = 1000$")
plt.xlim([0, 310])
plt.show()

# ERDOSRENYI
df.loc[df['Gen'] == 'ERDOSRENYI'].plot(kind='scatter', x='Thinning', y='Independence-Rate', s=5)
plt.title("ErdosRenyi graph: $n = 500, p = 0.5$")
plt.xlim([0, 310])
plt.show()

# HYPER
df.loc[(df['Gen'] == 'HYPER') & (df['Param2'] == '6.0') & (df['Param3'] == '0.0')].plot(kind='scatter', x='Thinning', y='Independence-Rate', s=5)
plt.title("Hyperbolic graph: $n = 1000, \gamma = -2.1, avgdeg = 6, T = 0.0$")
plt.xlim([0, 310])
plt.show()

# Curveball-Uniform
print("Curveball-Uniform")
# PLDHH
df.loc[(df['Nodes'] == 1000) & (df['Gen'] == 'PLDHH') & (df['Randomizer'] == 'CB_UNIFORM')].plot(kind='scatter', x='Thinning', y='Independence-Rate', s=5)
plt.title("Powerlaw graph: $n = 1000, \gamma = -2, mindeg = 50, maxdeg = 1000$")
#plt.ylim([0, 1])
#plt.xlim([0, 310])
plt.show()

df.loc[(df['Label'] == 'CURVEBALL_BIG')].plot(kind='scatter', x='Thinning', y='Independence-Rate', s=5)
plt.title("Powerlaw graph: $n = 10000, \gamma = -2, mindeg = 1, maxdeg = 10000$")
plt.show()
# Out:
# Edge-Switching Markov Chain
# Curveball-Uniform
